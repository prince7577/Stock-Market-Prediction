# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_excel(r'C:\Users\xhiva\OneDrive\Desktop\Stock Predicttion\Minor Project Data set (Stock Price Prediction).xlsx', index_col='Date', parse_dates = True)

data.head(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# 2018-02-12  252.139999  259.149994  249.000000  257.950012  257.950012
# 2018-02-13  257.290009  261.410004  254.699997  258.269989  258.269989
# 2018-02-14  260.470001  269.880005  260.329987  266.000000  266.000000
# 2018-02-15  270.029999  280.500000  267.630005  280.269989  280.269989
# 2018-02-16  278.730011  281.959991  275.690002  278.519989  278.519989
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# 2018-02-08   9306700
# 2018-02-09  16906900
# 2018-02-12   8534900
# 2018-02-13   6855200
# 2018-02-14  10972000
# 2018-02-15  10759700
# 2018-02-16   8312400

# %%
data.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
plt.figure(figsize=(12, 5), dpi=200)

plt.title("Stock Market")
plt.xlabel('Date')
plt.ylabel('Prices')

plt.plot(data['Open'], label='Open', color='green')
plt.plot(data['Close'], label='Close', color='red')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 5), dpi=200)

plt.title("Stock Market")
plt.xlabel('Date')
plt.ylabel('Prices')

plt.plot(data['High'], label='High', color='blue')
plt.plot(data['Low'], label='Low', color='purple')

plt.legend()
plt.show()

# %%
training_data = data[data.index < '2020-01-01']
testing_data = data[data.index >= '2020-01-01']


training_data.shape, testing_data.shape
# Out:
# ((480, 6), (529, 6))

# %%
training_data = training_data.filter(['Open', 'High', 'Low', 'Close', 'Volume'])
training_data.shape
# Out:
# (480, 5)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_training_data = scaler.fit_transform(training_data)

scaled_training_data
# Out:
# array([[0.14979196, 0.09996523, 0.10338193, 0.11010854, 0.17514821],
#        [0.07350901, 0.09301123, 0.07572177, 0.1720244 , 0.18755619],
#        [0.17422377, 0.12633298, 0.18201811, 0.16575716, 0.12346275],
#        ...,
#        [0.52832599, 0.48197737, 0.52119889, 0.51439836, 0.0534978 ],
#        [0.50762822, 0.45514609, 0.50387679, 0.48317032, 0.04064826],
#        [0.46986023, 0.43040114, 0.49414355, 0.48457509, 0.0300402 ]])

# %%
X_train = []
y_train = []

for i in range(60, scaled_training_data.shape[0]-60):
    X_train.append(scaled_training_data[i-60:i])
    y_train.append(scaled_training_data[i,[0, 3]])

# %%
X_train, y_train = np.array(X_train), np.array(y_train)

X_train.shape, y_train.shape
# Out:
# ((360, 60, 5), (360, 2))

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from sklearn.metrics import mean_squared_error

# %%
model = Sequential()

model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 5)))
model.add(Dropout(0.2))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50))
model.add(Dropout(0.2))

model.add(Dense(units = 2))
# Out:
# C:\Users\xhiva\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer = Adam(), loss = 'mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 50)         │        11,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 60, 50)         │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 60, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2)              │           102 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,702 (201.96 KB)
#  Trainable params: 51,702 (201.96 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 0.2386 - val_loss: 0.0698
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0476 - val_loss: 0.0364
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0309 - val_loss: 0.0284
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0256 - val_loss: 0.0276
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0207 - val_loss: 0.0172
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0188 - val_loss: 0.0165
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0200 - val_loss: 0.0325
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0167 - val_loss: 0.0276
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0137 - val_loss: 0.0175
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0158 - val_loss: 0.0173
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0169 - val_loss: 0.0205
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0190 - val_loss: 0.0192
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0161 - val_loss: 0.0134
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0159 - val_loss: 0.0148
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0145 - val_loss: 0.0198
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0141 - val_loss: 0.0232
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0140 - val_loss: 0.0227
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0134 - val_loss: 0.0235
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0148 - val_loss: 0.0203
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0132 - val_loss: 0.0166
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0130 - val_loss: 0.0171
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0149 - val_loss: 0.0211
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0138 - val_loss: 0.0194
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0131 - val_loss: 0.0223
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0134 - val_loss: 0.0217
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0124 - val_loss: 0.0199
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0148 - val_loss: 0.0178
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0127 - val_loss: 0.0195
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0102 - val_loss: 0.0273
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0155 - val_loss: 0.0228
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0116 - val_loss: 0.0227
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0119 - val_loss: 0.0151
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0131 - val_loss: 0.0200
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0132 - val_loss: 0.0210
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0130 - val_loss: 0.0277
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0125 - val_loss: 0.0263
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0119 - val_loss: 0.0276
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0113 - val_loss: 0.0190
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0118 - val_loss: 0.0190
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0133 - val_loss: 0.0154
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0157 - val_loss: 0.0165
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0136 - val_loss: 0.0171
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0124 - val_loss: 0.0307
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0125 - val_loss: 0.0326
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0164 - val_loss: 0.0251
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0150 - val_loss: 0.0269
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0111 - val_loss: 0.0217
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0121 - val_loss: 0.0198
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0108 - val_loss: 0.0203
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0111 - val_loss: 0.0250
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0114 - val_loss: 0.0290
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0108 - val_loss: 0.0194
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0092 - val_loss: 0.0284
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0127 - val_loss: 0.0260
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0108 - val_loss: 0.0231
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0097 - val_loss: 0.0274
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0103 - val_loss: 0.0280
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0113 - val_loss: 0.0287
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0116 - val_loss: 0.0246
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0093 - val_loss: 0.0213
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0099 - val_loss: 0.0198
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0109 - val_loss: 0.0202
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0093 - val_loss: 0.0176
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0125 - val_loss: 0.0235
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0116 - val_loss: 0.0301
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0107 - val_loss: 0.0279
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0112 - val_loss: 0.0247
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0095 - val_loss: 0.0211
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0100 - val_loss: 0.0246
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0106 - val_loss: 0.0203
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0096 - val_loss: 0.0225
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0094 - val_loss: 0.0352
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0100 - val_loss: 0.0218
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0103 - val_loss: 0.0180
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0107 - val_loss: 0.0174
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0104 - val_loss: 0.0247
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0092 - val_loss: 0.0257
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0080 - val_loss: 0.0260
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0092 - val_loss: 0.0195
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0086 - val_loss: 0.0200
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0083 - val_loss: 0.0234
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0076 - val_loss: 0.0259
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0100 - val_loss: 0.0172
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0093 - val_loss: 0.0248
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0081 - val_loss: 0.0269
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0088 - val_loss: 0.0221
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0086 - val_loss: 0.0208
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0079 - val_loss: 0.0218
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0095 - val_loss: 0.0147
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0096 - val_loss: 0.0197
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0080 - val_loss: 0.0230
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0080 - val_loss: 0.0225
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0084 - val_loss: 0.0223
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0076 - val_loss: 0.0188
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0069 - val_loss: 0.0201
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0073 - val_loss: 0.0249
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0081 - val_loss: 0.0286
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0066 - val_loss: 0.0184
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0070 - val_loss: 0.0223
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0063 - val_loss: 0.0173

# %%
metrics = pd.DataFrame(model.history.history)

# %%
metrics.head()
# Out:
#        loss  val_loss
# 0  0.145510  0.069808
# 1  0.042703  0.036403
# 2  0.030350  0.028356
# 3  0.027313  0.027569
# 4  0.022066  0.017221

# %%
metrics[['loss','val_loss']].plot(figsize=(12, 5))
plt.title("Loss Vs Val_loss")
plt.xlabel('change_over_time')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
model.save('stock_predictor_3.keras')

# %%
testing_data = testing_data.filter(['Open', 'High', 'Low', 'Close', 'Volume'])
testing_data.shape
# Out:
# (529, 5)

# %%
past_60_days_data = training_data.tail(60)

# %%
import pandas as pd

new_testing_data = pd.concat([past_60_days_data, testing_data], ignore_index=True)
print(new_testing_data.shape)
# Out:
# (589, 5)

# %%
scaled_testing_data = scaler.transform(new_testing_data)
scaled_testing_data
# Out:
# array([[0.20308327, 0.15084608, 0.22023649, 0.21924462, 0.07991155],
#        [0.20863117, 0.14418177, 0.21671719, 0.19903829, 0.07549241],
#        [0.19257436, 0.11793003, 0.18333799, 0.18180342, 0.08467826],
#        ...,
#        [1.14333721, 1.16672474, 1.07368724, 1.05678324, 0.218593  ],
#        [1.00032005, 1.03506038, 0.95160853, 0.9277649 , 0.13984299],
#        [0.92494395, 0.93949929, 0.90959597, 0.95245563, 0.10219875]])

# %%
X_test = []
y_test = []

for i in range(60, scaled_testing_data.shape[0]):
    X_test.append(scaled_testing_data[i-60:i])
    y_test.append(scaled_testing_data[i,[0,3]])

# %%
X_test, y_test = np.array(X_test), np.array(y_test)

X_test.shape, y_test.shape
# Out:
# ((529, 60, 5), (529, 2))

# %%
loss = model.evaluate(X_test, y_test)
loss
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0434
# 0.08554689586162567

# %%
model = keras.models.load_model('stock_predictor_3.keras')

# %%
predictions = model.predict(X_test)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step

# %%
mean_error = mean_squared_error(y_test, predictions)

mean_error
# Out:
# 0.08636421511248836

# %%
scaler.scale_
# Out:
# array([5.33447115e-03, 5.79508587e-03, 5.49903794e-03, 5.40277714e-03,
#        1.77332948e-08])

# %%
scale_open = 1/5.05970449e-03
scale_close = 1/5.00575662e-03

# %%
predicted_open = predictions[:, 0]
predicted_close = predictions[:, 1]

predicted_open = predicted_open * scale_open
predicted_close = predicted_close * scale_close

# %%
actual_open = y_test[:, 0]
actual_close = y_test[:, 1]

actual_open = actual_open * scale_open
actual_close = actual_close * scale_close

# %%
new_open_df = pd.DataFrame({"Actual Open": actual_open, "Predicted Open": predicted_open})

new_open_df.head(40)
# Out:
#     Actual Open  Predicted Open
# 0     97.185833      119.257034
# 1     97.902753      117.156601
# 2     94.043992      115.749687
# 3    108.118969      115.395958
# 4    102.868519      115.748848
# 5    113.949274      117.177956
# 6    108.814814      119.111404
# 7    103.195351      119.924355
# 8    116.479599      120.143616
# 9    110.448974      119.881203
# 10   115.530731      120.289612
# 11   112.894969      120.885475
# 12   111.840664      121.280647
# 13   103.986080      121.252136
# 14    97.122577      119.717102
# 15   120.760074      118.922424
# 16   118.113791      120.504211
# 17   118.039982      122.309982
# 18   121.329408      123.911438
# 19   113.000406      124.660637
# 20   119.631993      124.687607
# 21   119.473821      124.227737
# 22   133.981067      124.856453
# 23   148.878400      127.524796
# 24   143.048095      131.451553
# 25   138.240468      134.745087
# 26   138.198286      136.636993
# 27   147.423454      137.495117
# 28   151.039712      138.291824
# 29   150.807763      139.759094
# 30   155.562689      141.477463
# 31   153.274833      142.986481
# 32   162.573810      144.688431
# 33   160.929097      146.620636
# 34   159.632291      147.741959
# 35   137.945264      147.957306
# 36   145.578420      145.417862
# 37   139.579424      141.834259
# 38   145.009086      140.153503
# 39   137.365376      140.448883

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(15, 6), dpi=200)

plt.title("Stock Market Open Price")
plt.xlabel('Timestamps')
plt.ylabel('Open')

plt.plot(new_open_df['Actual Open'], color='green')
plt.plot(new_open_df['Predicted Open'], color='red')

plt.legend(['Test Open', 'Prediction'], loc='upper left')
plt.savefig('stock_prediction_open_3.png', dpi=200)
plt.show()

# %%
new_close_df = pd.DataFrame({"Actual Close": actual_close, "Predicted Close": predicted_close})

new_close_df.head()
# Out:
#    Actual Close  Predicted Close
# 0    103.538468       122.267281
# 1     99.318351       120.268082
# 2    110.035920       118.865417
# 3    104.553025       118.413292
# 4    113.737987       118.574684

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(15, 6), dpi=200)

plt.title("Stock Market Close Price")
plt.xlabel('Timestamps')
plt.ylabel('Close')

plt.plot(new_close_df['Actual Close'], color='purple')
plt.plot(new_close_df['Predicted Close'], color='blue')

plt.legend(['Test Close', 'Prediction'], loc='upper left')
plt.savefig('stock_prediction_close_3.png', dpi=200)
plt.show()
